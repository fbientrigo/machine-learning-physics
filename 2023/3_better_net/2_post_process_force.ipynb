# %%
import deepql
import matplotlib.pyplot as plt
import numpy as np
import torch

# %% [markdown]
# Función de activación para la gaussiana

# %%
# better activation function
x_arr = torch.tensor( np.linspace(-5,5,1000) )
g_arr = deepql.diffnet.narrow_gaussian(x_arr)
plt.plot(x_arr, g_arr)

# %% [markdown]
# Funciones tipo posición y velocidad
# - Con postprocesado opcional

# %%
model = deepql.diffnet.diffNet(
    depth=150, dt=1e-2, N=300, lower_limit=1.0, upper_limit=60,
    post_process=True, pp_mu=0, pp_epsilon=1e-2, force_type='position'
)

model.plot_parameters()

# %%
model = deepql.diffnet.diffNet(
    depth=150, dt=1e-2, N=300, lower_limit=-50, upper_limit=60,
    post_process=True, pp_mu=0, pp_epsilon=1e-2, force_type='velocity'
)

model.plot_parameters()
